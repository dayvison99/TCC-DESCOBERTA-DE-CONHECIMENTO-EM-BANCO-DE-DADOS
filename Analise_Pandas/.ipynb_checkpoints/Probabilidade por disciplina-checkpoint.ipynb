# %% [markdown]
# # SASA - SISTEMA DE ANALISE DE SISTUAÇÕES ACADEMICA

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Lendo os dados

# %%
dados = pd.read_csv('dateset.csv')

# %%
df = pd.DataFrame(dados)

# %%
df[['disciplina','situacaoDisciplina']]
# Out:
#                    disciplina situacaoDisciplina
# 0                   Algoritmo           APROVADO
# 1                   Algoritmo          REPROVADO
# 2                   Algoritmo          REPROVADO
# 3                   Algoritmo           APROVADO
# 4                   Algoritmo           APROVADO
# 5                   Algoritmo           APROVADO
# 6                   Algoritmo           APROVADO
# 7                   Algoritmo           APROVADO
# 8                   Algoritmo          REPROVADO
# 9                   Algoritmo           APROVADO
# 10                  Algoritmo           APROVADO
# 11                  Algoritmo          REPROVADO
# 12                  Algoritmo           APROVADO
# 13                  Algoritmo           APROVADO
# 14                  Algoritmo          REPROVADO
# 15                  Algoritmo           APROVADO
# 16                  Algoritmo           APROVADO
# 17                  Algoritmo           APROVADO
# 18                  Algoritmo           APROVADO
# 19                  Algoritmo           APROVADO
# 20                  Algoritmo          REPROVADO
# 21                  Algoritmo           APROVADO
# 22                  Algoritmo           APROVADO
# 23                  Algoritmo           APROVADO
# 24                  Algoritmo           APROVADO
# 25                  Algoritmo           APROVADO
# 26                  Algoritmo           APROVADO
# 27                  Algoritmo           APROVADO
# 28                  Algoritmo           APROVADO
# 29                  Algoritmo           APROVADO
# ...                       ...                ...
# 10397  Metodologia_Cientifica           APROVADO
# 10398  Metodologia_Cientifica          REPROVADO
# 10399  Metodologia_Cientifica           APROVADO
# 10400  Metodologia_Cientifica          REPROVADO
# 10401  Metodologia_Cientifica          REPROVADO
# 10402  Metodologia_Cientifica        MATRICULADO
# 10403  Metodologia_Cientifica        MATRICULADO
# 10404  Metodologia_Cientifica        MATRICULADO
# 10405  Metodologia_Cientifica        MATRICULADO
# 10406  Metodologia_Cientifica        MATRICULADO
# 10407  Metodologia_Cientifica        MATRICULADO
# 10408  Metodologia_Cientifica        MATRICULADO
# 10409  Metodologia_Cientifica        MATRICULADO
# 10410  Metodologia_Cientifica        MATRICULADO
# 10411  Metodologia_Cientifica        MATRICULADO
# 10412  Metodologia_Cientifica        MATRICULADO
# 10413  Metodologia_Cientifica        MATRICULADO
# 10414  Metodologia_Cientifica        MATRICULADO
# 10415  Metodologia_Cientifica          CANCELADO
# 10416  Metodologia_Cientifica        MATRICULADO
# 10417  Metodologia_Cientifica        MATRICULADO
# 10418  Metodologia_Cientifica          CANCELADO
# 10419  Metodologia_Cientifica        MATRICULADO
# 10420  Metodologia_Cientifica          CANCELADO
# 10421  Metodologia_Cientifica        MATRICULADO
# 10422  Metodologia_Cientifica        MATRICULADO
# 10423  Metodologia_Cientifica        MATRICULADO
# 10424  Metodologia_Cientifica        MATRICULADO
# 10425  Metodologia_Cientifica        MATRICULADO
# 10426  Metodologia_Cientifica        MATRICULADO
#
# [10427 rows x 2 columns]

# %%
dados[(dados['disciplina']=='') &  (dados['situacaoDisciplina']=='APROVADO')]

# %% [markdown]
# ##### Contando Cada Situação Possivel (APROVADO e REPROVADO)

# %%
total=dados['situacaoDisciplina'].count()

# %%
aprovado = dados[dados.situacaoDisciplina=='APROVADO'].count()

# %%
reprovado = dados[dados.situacaoDisciplina=='REPROVADO'].count()

# %% [markdown]
# #### Probabilidade para cada disciplina

# %%
def resultados(disciplina,situacaoDisciplina):
        a = []
        for i in range(1):
            probabilidadeTotal = dados.loc[(dados['disciplina']==disciplina)].count()
            probabilidade = dados.loc[(dados['disciplina']==disciplina) & (dados['situacaoDisciplina']==situacaoDisciplina)].count()
            a = probabilidade/probabilidadeTotal
       
            return "A probabilidaded  aluno ser ",situacaoDisciplina,'em', disciplina, a[i],'%'

# %%
resultados('Algoritmo','APROVADO')
# Out:
# ('A probabilidaded  aluno ser ',
#  'APROVADO',
#  'em',
#  'Algoritmo',
#  0.30559006211180123,
#  '%')

# %%
resultados('TGA','APROVADO')
# Out:
# ('A probabilidaded  aluno ser ',
#  'APROVADO',
#  'em',
#  'TGA',
#  0.8036529680365296,
#  '%')
