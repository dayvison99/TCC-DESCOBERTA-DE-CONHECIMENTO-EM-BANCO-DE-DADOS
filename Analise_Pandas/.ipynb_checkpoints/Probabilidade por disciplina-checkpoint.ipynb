# %% [markdown]
# # SASA - SISTEMA DE ANALISE DE SISTUAÇÕES ACADEMICA

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Lendo os dados

# %%
dados = pd.read_csv('dateset.csv')

# %%
date = pd.DataFrame(dados)

# %%
grouped = date.groupby('disciplina')

# %%
resultado = dados.groupby(['disciplina']).describe()
    
resultado
# Out:
#                                   situacaoDisciplina
#                                                count unique        top freq
# disciplina
# Algoritmo                                        805      4  REPROVADO  514
# Analise_Projeto_Sistema                          228      4   APROVADO  154
# Arquitetura_Organizacao                          474      4  REPROVADO  228
# Arquitetura_Software                             129      4   APROVADO  100
# Auditoria_Seguranca                              123      4   APROVADO   77
# Banco_Dados_I                                    335      3   APROVADO  188
# Banco_Dados_II                                   249      4   APROVADO  151
# Contabilidade                                    216      4   APROVADO  159
# Empreendedorismo                                 224      4   APROVADO  151
# Engenharia_Software                              211      4   APROVADO  142
# Estatisticas                                     464      4  REPROVADO  221
# Fundamentos_Computacao                           435      3   APROVADO  282
# Fundamentos_Sistemas_Informacao                  330      4  REPROVADO  159
# Gerencia_Recursos_Informacional                  148      4   APROVADO  113
# Gerencia_projetos                                125      4   APROVADO   87
# Ingles                                           411      3   APROVADO  304
# Interface_Homem_Maquina                          156      4   APROVADO   69
# Legislacao_Aplicada                              204      4   APROVADO  153
# Lingua_Portuguesa                                465      4   APROVADO  323
# Logica_Matematica                                393      3  REPROVADO  206
# Matematica_Computacional                         469      3  REPROVADO  294
# Metodologia_Cientifica                           266      4   APROVADO  138
# Metodologias_Ageis                               106      4   APROVADO   90
# Modelos_Paradigmas_Programacao                   163      3   APROVADO  124
# Processo_Unificado                               131      4   APROVADO  112
# Programacao_Estruturada                          482      4  REPROVADO  274
# Programacao_Orientada_Objeto                     224      5   APROVADO  136
# Programacao_Sistemas_Corporativos                196      4   APROVADO  113
# Programacao_Web_I                                301      4   APROVADO  173
# Programacao_Web_II                                82      4   APROVADO   63
# Qualidade_de_Software                             68      4   APROVADO   53
# Redes_Computadores_I                             341      4   APROVADO  159
# Redes_Computadores_II                            199      4   APROVADO  135
# Seminarios                                       137      4   APROVADO  102
# Sistemas_Operacionais                            611      3   APROVADO  317
# TGA                                              438      3   APROVADO  352
# Topicos_Especiais                                156      4   APROVADO   85

# %%
resultado.filter(items=['periodo'], title("Arr"))
# Out:
# Empty DataFrame
# Columns: []
# Index: [Algoritmo, Analise_Projeto_Sistema, Arquitetura_Organizacao, Arquitetura_Software, Auditoria_Seguranca, Banco_Dados_I, Banco_Dados_II, Contabilidade, Empreendedorismo, Engenharia_Software, Estatisticas, Fundamentos_Computacao, Fundamentos_Sistemas_Informacao, Gerencia_Recursos_Informacional, Gerencia_projetos, Ingles, Interface_Homem_Maquina, Legislacao_Aplicada, Lingua_Portuguesa, Logica_Matematica, Matematica_Computacional, Metodologia_Cientifica, Metodologias_Ageis, Modelos_Paradigmas_Programacao, Processo_Unificado, Programacao_Estruturada, Programacao_Orientada_Objeto, Programacao_Sistemas_Corporativos, Programacao_Web_I, Programacao_Web_II, Qualidade_de_Software, Redes_Computadores_I, Redes_Computadores_II, Seminarios, Sistemas_Operacionais, TGA, Topicos_Especiais]

# %% [markdown]
# ##### Contando Cada Situação Possivel (APROVADO e REPROVADO)

# %%
total=dados['situacaoDisciplina'].count()

# %%
aprovado = dados[dados.situacaoDisciplina=='APROVADO'].count()

# %%
reprovado = dados[dados.situacaoDisciplina=='REPROVADO'].count()

# %% [markdown]
# #### Probabilidade para cada disciplina

# %%
def resultados(disciplinas): #disciplina,situacaoDisciplina
    #print(disciplinas)
    a = []
        #for i in range(1):
        #    probabilidadeTotal = dados.loc[(dados['disciplina']==disciplina)].count()
        #    probabilidade = dados.loc[(dados['disciplina']==disciplina) & (dados['situacaoDisciplina']==situacaoDisciplina)].count()
        #    a = probabilidade/probabilidadeTotal
       
        #    return "A probabilidaded  aluno ser ",situacaoDisciplina,'em', disciplina, a[i],'%'
        
    for d in disciplinas:
        probabilidadeTotal = dados.loc[(dados['disciplina']==d[0])].count()
        probabilidade = dados.loc[(dados['disciplina']==d[0]) & (dados['situacaoDisciplina']==d[1])].count()
        a.append([d[0], d[1], probabilidade/probabilidadeTotal])
    
    msg = """A probabilidade do aluno obter um determinado resultado para as seguintes disciplinas:
    |          Disciplina         |    Situação  |    Probabilidade    |"""
    for i in a:
        msg+= '           |           {0}           |   {1}  |    {2}'.format(i[0], i[1], i[2])

    return msg

# %%
resultados([('Algoritmo','REPROVADO'), ('TGA','APROVADO'),('Lingua_Portuguesa','APROVADO')])
# Out:
# 'A probabilidade do aluno obter um determinado resultado para as seguintes disciplinas:\n    |          Disciplina         |    Situação  |    Probabilidade    |           |           Algoritmo           |   REPROVADO  |    disciplina            0.638509\nsituacaoDisciplina    0.638509\ndtype: float64           |           TGA           |   APROVADO  |    disciplina            0.803653\nsituacaoDisciplina    0.803653\ndtype: float64           |           Lingua_Portuguesa           |   APROVADO  |    disciplina            0.694624\nsituacaoDisciplina    0.694624\ndtype: float64'

# %%
b=[('Algoritmo','REPROVADO'), ('TGA','APROVADO'),('Lingua_Portuguesa','APROVADO')]

# %%
resultados(b)
# Out:
# 'A probabilidade do aluno obter um determinado resultado para as seguintes disciplinas:\n    |          Disciplina         |    Situação  |    Probabilidade    |           |           Algoritmo           |   REPROVADO  |    disciplina            0.638509\nsituacaoDisciplina    0.638509\ndtype: float64           |           TGA           |   APROVADO  |    disciplina            0.803653\nsituacaoDisciplina    0.803653\ndtype: float64           |           Lingua_Portuguesa           |   APROVADO  |    disciplina            0.694624\nsituacaoDisciplina    0.694624\ndtype: float64'
