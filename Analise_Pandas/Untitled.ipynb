# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# %%
disciplina = pd.read_csv('dateset.csv')

# %%
plt.hist(disciplina,bins = 100, normed = True)

plt.show()
