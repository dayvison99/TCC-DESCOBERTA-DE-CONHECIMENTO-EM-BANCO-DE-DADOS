# %% [markdown]
# # SASA - SISTEMA DE ANALISE DE SISTUAÇÕES ACADEMICA

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Lendo os dados

# %%
dados = pd.read_csv('dateset.csv')

# %%
df = pd.DataFrame(dados)

# %%
dados
# Out:
#        periodo              disciplina situacaoDisciplina
# 0            1               Algoritmo           APROVADO
# 1            1               Algoritmo          REPROVADO
# 2            1               Algoritmo          REPROVADO
# 3            1               Algoritmo           APROVADO
# 4            1               Algoritmo           APROVADO
# 5            1               Algoritmo           APROVADO
# 6            1               Algoritmo           APROVADO
# 7            1               Algoritmo           APROVADO
# 8            1               Algoritmo          REPROVADO
# 9            1               Algoritmo           APROVADO
# 10           1               Algoritmo           APROVADO
# 11           1               Algoritmo          REPROVADO
# 12           1               Algoritmo           APROVADO
# 13           1               Algoritmo           APROVADO
# 14           1               Algoritmo          REPROVADO
# 15           1               Algoritmo           APROVADO
# 16           1               Algoritmo           APROVADO
# 17           1               Algoritmo           APROVADO
# 18           1               Algoritmo           APROVADO
# 19           1               Algoritmo           APROVADO
# 20           1               Algoritmo          REPROVADO
# 21           1               Algoritmo           APROVADO
# 22           1               Algoritmo           APROVADO
# 23           1               Algoritmo           APROVADO
# 24           1               Algoritmo           APROVADO
# 25           1               Algoritmo           APROVADO
# 26           1               Algoritmo           APROVADO
# 27           1               Algoritmo           APROVADO
# 28           1               Algoritmo           APROVADO
# 29           1               Algoritmo           APROVADO
# ...        ...                     ...                ...
# 10397        6  Metodologia_Cientifica           APROVADO
# 10398        6  Metodologia_Cientifica          REPROVADO
# 10399        6  Metodologia_Cientifica           APROVADO
# 10400        6  Metodologia_Cientifica          REPROVADO
# 10401        6  Metodologia_Cientifica          REPROVADO
# 10402        6  Metodologia_Cientifica        MATRICULADO
# 10403        6  Metodologia_Cientifica        MATRICULADO
# 10404        6  Metodologia_Cientifica        MATRICULADO
# 10405        6  Metodologia_Cientifica        MATRICULADO
# 10406        6  Metodologia_Cientifica        MATRICULADO
# 10407        6  Metodologia_Cientifica        MATRICULADO
# 10408        6  Metodologia_Cientifica        MATRICULADO
# 10409        6  Metodologia_Cientifica        MATRICULADO
# 10410        6  Metodologia_Cientifica        MATRICULADO
# 10411        6  Metodologia_Cientifica        MATRICULADO
# 10412        6  Metodologia_Cientifica        MATRICULADO
# 10413        6  Metodologia_Cientifica        MATRICULADO
# 10414        6  Metodologia_Cientifica        MATRICULADO
# 10415        6  Metodologia_Cientifica          CANCELADO
# 10416        6  Metodologia_Cientifica        MATRICULADO
# 10417        6  Metodologia_Cientifica        MATRICULADO
# 10418        6  Metodologia_Cientifica          CANCELADO
# 10419        6  Metodologia_Cientifica        MATRICULADO
# 10420        6  Metodologia_Cientifica          CANCELADO
# 10421        6  Metodologia_Cientifica        MATRICULADO
# 10422        6  Metodologia_Cientifica        MATRICULADO
# 10423        6  Metodologia_Cientifica        MATRICULADO
# 10424        6  Metodologia_Cientifica        MATRICULADO
# 10425        6  Metodologia_Cientifica        MATRICULADO
# 10426        6  Metodologia_Cientifica        MATRICULADO
#
# [10427 rows x 3 columns]

# %%
dados[(dados['disciplina']=='') &  (dados['situacaoDisciplina']=='APROVADO')]

# %% [markdown]
# ##### Contando Cada Situação Possivel (APROVADO e REPROVADO)

# %%
total=dados['situacaoDisciplina'].count()

# %%
aprovado = dados[dados.situacaoDisciplina=='APROVADO'].count()

# %%
reprovado = dados[dados.situacaoDisciplina=='REPROVADO'].count()

# %% [markdown]
# #### Probabilidade para cada disciplina

# %%
def resultados(disciplina,situacaoDisciplina):
        a = []
        for i in range(1):
            probabilidadeTotal = dados.loc[(dados['disciplina']==disciplina)].count()
            probabilidade = dados.loc[(dados['disciplina']==disciplina) & (dados['situacaoDisciplina']==situacaoDisciplina)].count()
            a = probabilidade/probabilidadeTotal
       
            return "A probabilidaded  aluno ser ",situacaoDisciplina,'em', disciplina, a[i],'%'

# %%
resultados('Algoritmo','APROVADO')
# Out:
# ('A probabilidaded  aluno ser ',
#  'APROVADO',
#  'em',
#  'Algoritmo',
#  0.30559006211180123,
#  '%')

# %%
resultados('TGA','APROVADO')
# Out:
# ('A probabilidaded  aluno ser ',
#  'APROVADO',
#  'em',
#  'TGA',
#  0.8036529680365296,
#  '%')
